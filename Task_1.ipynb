# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
img1_path = 'D:\Task 1\img 1.JPG'
img2_path = 'D:\Task 1\img 2.JPG'
csv_path = 'D:\Task 1\colours.csv'

# %%
img2 = cv2.imread(img1_path)
img1 = cv2.imread(img2_path)

# %%
plt.figure(figsize=(20,8))
plt.imshow(img1)

# %%
grid_RGB = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,8))
plt.imshow(grid_RGB)

# %%
index = ['colour', 'colour_name', 'hex', 'R', 'G', 'B']
df = pd.read_csv(csv_path, names=index, header=None)

# %%
clicked = False
r = g = b = xpos = ypos = 0

# %%
def get_color_name (R,G,B):
    minimum = 1000
    for i in range (len(df)):
        d = abs(R - int(df.loc[i,'R'])) + abs(G - int(df.loc[i,'G'])) + abs(B - int(df.loc[i,'B']))
        if d <= minimum:
            minimum = d
            cname = df.loc[i,'colour_name']
            
    return cname

# %%
def draw_function(event, x, y, flags, params):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        global b, g, r, xpos, ypos, clicked
        clicked = True
        xpos = x
        ypos = y
        b,g,r = img1[y,x]
        b = int(b)
        g = int(g)
        r = int(r)

# %%
cv2.namedWindow('Task 1')
cv2.setMouseCallback('Task 1', draw_function)

# %%
while True:
    cv2.imshow('Task 1',img1)
    if clicked:
        cv2.rectangle(img1, (20,20), (600,60), (b,g,r), -1)
        
        text = get_color_name(r,g,b) + ' R  =' + str(r) + ' G = ' + str(g) + ' B = ' + str(b)
        
        cv2.putText(img1, text, (50,50), 2,0.8, (255,255,255),2,cv2.LINE_AA)
        
    if cv2.waitKey(20) & 0xFF == 27:
            break
            
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e65d28f5afce> in <module>
#       4         cv2.rectangle(img1, (20,20), (600,60), (b,g,r), -1)
#       5
# ----> 6         text = get_color_name(r,g,b) + ' R  =' + str(r) + ' G = ' + str(g) + ' B = ' + str(b)
#       7
#       8         cv2.putText(img1, text, (50,50), 2,0.8, (255,255,255),2,cv2.LINE_AA)
#
# <ipython-input-9-52b787f2cb34> in get_color_name(R, G, B)
#       2     minimum = 1000
#       3     for i in range (len(df)):
# ----> 4         d = abs(R - int(df.loc[i,'R'])) + abs(G - int(df.loc[i,'G'])) + abs(B - int(df.loc[i,'B']))
#       5         if d <= minimum:
#       6             minimum = d
#
# c:\users\adi\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     867             if self._is_scalar_access(key):
#     868                 try:
# --> 869                     return self.obj._get_value(*key, takeable=self._takeable)
#     870                 except (KeyError, IndexError, AttributeError):
#     871                     # AttributeError for IntervalTree get_value
#
# c:\users\adi\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3008             return series._values[index]
#    3009
# -> 3010         series = self._get_item_cache(col)
#    3011         engine = self.index._engine
#    3012
#
# c:\users\adi\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    3532         raise AbstractMethodError(self)
#    3533
# -> 3534     def _get_item_cache(self, item):
#    3535         """Return the cached item, item represents a label indexer."""
#    3536         cache = self._item_cache
#
# KeyboardInterrupt:
